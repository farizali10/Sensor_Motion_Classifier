# %%
import warnings
# Set the warnings to be ignored
warnings.filterwarnings('ignore')

import os
import sys
import logging
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LogisticRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt

from ydata_profiling import ProfileReport
import seaborn as sns
import pickle

# %% [markdown]
# # EDA:

# %%
df = pd.read_csv("D:\Data-Science-D-drive\Datasets-D-drive\sensor_placement\output_df.csv")

# %%
df["Output"].unique()
# Out:
# array(['bending1', 'bending2', 'cycling', 'lying', 'sitting', 'standing',
#        'walking'], dtype=object)

# %%
df.head()
# Out:
#    Unnamed: 0 # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  \
# 0           0               0      39.25       0.43      22.75       0.43
# 1           1             250      39.25       0.43      23.00       0.00
# 2           2             500      39.25       0.43      23.25       0.43
# 3           3             750      39.50       0.50      23.00       0.71
# 4           4            1000      39.50       0.50      24.00       0.00
#
#    avg_rss23  var_rss23    Output
# 0      33.75        1.3  bending1
# 1      33.00        0.0  bending1
# 2      33.00        0.0  bending1
# 3      33.00        0.0  bending1
# 4      33.00        0.0  bending1

# %%
df.rename(columns={"# Columns: time":"Time"},inplace=True)

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    Unnamed: 0  Time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0           0     0      39.25       0.43      22.75       0.43      33.75
# 1           1   250      39.25       0.43      23.00       0.00      33.00
# 2           2   500      39.25       0.43      23.25       0.43      33.00
# 3           3   750      39.50       0.50      23.00       0.71      33.00
# 4           4  1000      39.50       0.50      24.00       0.00      33.00
#
#    var_rss23    Output
# 0        1.3  bending1
# 1        0.0  bending1
# 2        0.0  bending1
# 3        0.0  bending1
# 4        0.0  bending1

# %%
df1.drop(columns="Unnamed: 0",inplace=True)

# %%
df1.head()
# Out:
#    Time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23  \
# 0     0      39.25       0.43      22.75       0.43      33.75        1.3
# 1   250      39.25       0.43      23.00       0.00      33.00        0.0
# 2   500      39.25       0.43      23.25       0.43      33.00        0.0
# 3   750      39.50       0.50      23.00       0.71      33.00        0.0
# 4  1000      39.50       0.50      24.00       0.00      33.00        0.0
#
#      Output
# 0  bending1
# 1  bending1
# 2  bending1
# 3  bending1
# 4  bending1

# %%
df1.isnull().sum()
# Out:
# Time           0
# avg_rss12    480
# var_rss12    480
# avg_rss13    480
# var_rss13    480
# avg_rss23    480
# var_rss23    480
# Output         0
# dtype: int64

# %%
test = df1[~df1.Time.str.isnumeric()]

# %%
test
# Out:
#                                          Time  avg_rss12  var_rss12  \
# 4800       0 32.50 0.50 0.00 0.00 19.00 1.00         NaN        NaN
# 4801     250 32.50 0.50 0.00 0.00 18.50 0.50         NaN        NaN
# 4802     500 32.75 0.43 1.00 0.00 18.00 0.00         NaN        NaN
# 4803     750 32.50 0.50 0.00 0.00 17.50 0.50         NaN        NaN
# 4804    1000 32.50 0.50 7.50 0.50 17.50 0.87         NaN        NaN
# ...                                       ...        ...        ...
# 5275  118750 28.67 0.47 4.67 1.25 17.33 0.47         NaN        NaN
# 5276  119000 27.50 0.50 5.50 2.50 17.25 1.30         NaN        NaN
# 5277  119250 28.00 0.00 6.67 0.94 17.00 1.00         NaN        NaN
# 5278  119500 28.00 0.00 5.00 0.82 17.00 0.71         NaN        NaN
# 5279  119750 28.00 0.00 0.00 0.00 17.00 1.00         NaN        NaN
#
#       avg_rss13  var_rss13  avg_rss23  var_rss23    Output
# 4800        NaN        NaN        NaN        NaN  bending2
# 4801        NaN        NaN        NaN        NaN  bending2
# 4802        NaN        NaN        NaN        NaN  bending2
# 4803        NaN        NaN        NaN        NaN  bending2
# 4804        NaN        NaN        NaN        NaN  bending2
# ...         ...        ...        ...        ...       ...
# 5275        NaN        NaN        NaN        NaN  bending2
# 5276        NaN        NaN        NaN        NaN  bending2
# 5277        NaN        NaN        NaN        NaN  bending2
# 5278        NaN        NaN        NaN        NaN  bending2
# 5279        NaN        NaN        NaN        NaN  bending2
#
# [480 rows x 8 columns]

# %%
pd.read_csv(r"D:\Data-Science-D-drive\sensor_placement_LogisticRegression\data\sensor_placement\bending2\dataset4.csv",sep="\t")
# Out:
#                                       # Task: bending2
# 0                                 # Frequency (Hz): 20
# 1                           # Clock (millisecond): 250
# 2                            # Duration (seconds): 120
# 3    # Columns: time,avg_rss12,var_rss12,avg_rss13,...
# 4                   0 32.50 0.50 0.00 0.00 19.00 1.00
# ..                                                 ...
# 479            118750 28.67 0.47 4.67 1.25 17.33 0.47
# 480            119000 27.50 0.50 5.50 2.50 17.25 1.30
# 481            119250 28.00 0.00 6.67 0.94 17.00 1.00
# 482            119500 28.00 0.00 5.00 0.82 17.00 0.71
# 483            119750 28.00 0.00 0.00 0.00 17.00 1.00
#
# [484 rows x 1 columns]

# %%
df1.columns
# Out:
# Index(['# Columns: time', 'avg_rss12', 'var_rss12', 'avg_rss13', 'var_rss13',
#        'avg_rss23', 'var_rss23', 'Output'],
#       dtype='object')

# %%
col_list = list(df1.columns)

for i in col_list:
    if df1[i].isna().sum() > 0:
        df1[i].fillna(df1[i].median(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# # Columns: time    0
# avg_rss12          0
# var_rss12          0
# avg_rss13          0
# var_rss13          0
# avg_rss23          0
# var_rss23          0
# Output             0
# dtype: int64

# %%
# Checking for duplicated records
df1.duplicated().sum()
# Out:
# 3359

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.shape[0]
# Out:
# 37440

# %%
df.shape[0]
# Out:
# 40799

# %%
100-(df1.shape[0]/df.shape[0]*100)
# Out:
# 8.233044927571754

# %% [markdown]
# We have lost 8.23% of the data after removing duplicates

# %%
for i in df1.columns:
    print(i,"---",df1[i].dtype)
# Out:
# # Columns: time --- object
# avg_rss12 --- float64
# var_rss12 --- float64
# avg_rss13 --- float64
# var_rss13 --- float64
# avg_rss23 --- float64
# var_rss23 --- float64
# Output --- object

# %%
df1[["# Columns: time"]].sample(10)
# Out:
#       # Columns: time
# 12874           98500
# 39464           26250
# 37132           43250
# 11877           89250
# 15844            1000
# 24264           66000
# 24034            8500
# 37209           62500
# 20545           96250
# 38317           99500

# %% [markdown]
# Renaming the column as it would cause errors due to space in the column name

# %%
df1.rename(columns={"# Columns: time":"Time"},inplace=True)

# %%
df1
# Out:
#          Time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0           0      39.25       0.43      22.75       0.43      33.75
# 1         250      39.25       0.43      23.00       0.00      33.00
# 2         500      39.25       0.43      23.25       0.43      33.00
# 3         750      39.50       0.50      23.00       0.71      33.00
# 4        1000      39.50       0.50      24.00       0.00      33.00
# ...       ...        ...        ...        ...        ...        ...
# 40794  118750      31.50       1.66      12.50       3.20      14.25
# 40795  119000      27.33       1.25      11.33       0.94      20.00
# 40796  119250      37.80       7.68      14.20       2.48      17.25
# 40797  119500      33.75       1.30      15.75       5.21      16.50
# 40798  119750      32.67       3.09      18.67       0.47      14.00
#
#        var_rss23    Output
# 0           1.30  bending1
# 1           0.00  bending1
# 2           0.00  bending1
# 3           0.00  bending1
# 4           0.00  bending1
# ...          ...       ...
# 40794       4.44   walking
# 40795       4.00   walking
# 40796       0.83   walking
# 40797       2.69   walking
# 40798       3.16   walking
#
# [37440 rows x 8 columns]

# %%
df[~df.Time.str.isnumeric()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20928\3773957986.py in ?()
# ----> 1 df[~df.Time.str.isnumeric()]
#
# d:\Data-Science-D-drive\sensor_placement_LogisticRegression\venv_sensor\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Time'

# %%
df1[~df1.Time.str.isnumeric()]
# Out:
#                                          Time  avg_rss12  var_rss12  \
# 4800       0 32.50 0.50 0.00 0.00 19.00 1.00        40.0        0.5
# 4801     250 32.50 0.50 0.00 0.00 18.50 0.50        40.0        0.5
# 4802     500 32.75 0.43 1.00 0.00 18.00 0.00        40.0        0.5
# 4803     750 32.50 0.50 0.00 0.00 17.50 0.50        40.0        0.5
# 4804    1000 32.50 0.50 7.50 0.50 17.50 0.87        40.0        0.5
# ...                                       ...        ...        ...
# 5275  118750 28.67 0.47 4.67 1.25 17.33 0.47        40.0        0.5
# 5276  119000 27.50 0.50 5.50 2.50 17.25 1.30        40.0        0.5
# 5277  119250 28.00 0.00 6.67 0.94 17.00 1.00        40.0        0.5
# 5278  119500 28.00 0.00 5.00 0.82 17.00 0.71        40.0        0.5
# 5279  119750 28.00 0.00 0.00 0.00 17.00 1.00        40.0        0.5
#
#       avg_rss13  var_rss13  avg_rss23  var_rss23    Output
# 4800       15.0       0.83      15.75        1.0  bending2
# 4801       15.0       0.83      15.75        1.0  bending2
# 4802       15.0       0.83      15.75        1.0  bending2
# 4803       15.0       0.83      15.75        1.0  bending2
# 4804       15.0       0.83      15.75        1.0  bending2
# ...         ...        ...        ...        ...       ...
# 5275       15.0       0.83      15.75        1.0  bending2
# 5276       15.0       0.83      15.75        1.0  bending2
# 5277       15.0       0.83      15.75        1.0  bending2
# 5278       15.0       0.83      15.75        1.0  bending2
# 5279       15.0       0.83      15.75        1.0  bending2
#
# [480 rows x 8 columns]

# %%
path = r"D:\Data-Science-D-drive\sensor_placement_LogisticRegression\data\sensor_placement\bending2\dataset2.csv"

# %%
data = pd.read_csv(path,sep="\t")

# %%
data.head(10)
# Out:
#                                     # Task: bending2
# 0                               # Frequency (Hz): 20
# 1                         # Clock (millisecond): 250
# 2                          # Duration (seconds): 120
# 3  # Columns: time,avg_rss12,var_rss12,avg_rss13,...
# 4                 0,27.00,0.00,24.00,0.00,19.00,1.00
# 5               250,27.00,0.00,24.00,0.00,19.75,0.83
# 6               500,27.00,0.00,23.50,0.50,20.00,1.22
# 7               750,27.00,0.00,24.00,0.00,14.75,1.48
# 8              1000,27.00,0.00,23.75,0.43,14.50,1.50
# 9              1250,27.00,0.00,23.33,0.47,17.33,2.05

# %%
#fig,ax = plt.subplots(figsize = (20,25))
#sns.boxplot(data = df1, ax = ax)
